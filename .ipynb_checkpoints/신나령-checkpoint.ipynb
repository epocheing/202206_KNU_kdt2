# %%
import pandas as pd

FILE='../week3_team5/Data_신나령/datalab.xlsx'
dataDF=pd.read_excel(FILE)
dataDF
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#             url  \
# 0            주제
# 1            범위
# 2            기간
# 3            성별
# 4           연령대
# ..          ...
# 366  2021-12-27
# 367  2021-12-28
# 368  2021-12-29
# 369  2021-12-30
# 370  2021-12-31
#
#     http://datalab.naver.com/keyword/trendResult.naver?hashKey=N_8cdae9e825b735201c8073f9b4fb4ace
# 0                                                   통검
# 1                                                   합계
# 2                         일간 : 2021-01-01 ~ 2021-12-31
# 3                                            전체(여성,남성)
# 4                                                   전체
# ..                                                 ...
# 366                                            0.60546
# ...

# %%
# 필요없는 행 삭제
dataDF.drop([0,1,2,3,4,5],inplace=True)

# %%
# 컬럼명 식별 가능하게 바꿔 줌
dataDF.rename(columns={'url':'date',
               'http://datalab.naver.com/keyword/trendResult.naver?hashKey=N_8cdae9e825b735201c8073f9b4fb4ace':'pepero'},
                inplace=True)

# %%
# 월-일 분리해서 저장
dateDF=dataDF.date.str.split('-',expand=True)
peperoDF=pd.concat([dateDF[[1,2]],dataDF.pepero],axis=1)
peperoDF.rename(columns={1:'month',2:'day'},inplace=True)

# %%
peperoDF.head()
# Out:
#    month day   pepero
# 6     01  01  0.49342
# 7     01  02  0.56345
# 8     01  03  0.58284
# 9     01  04  0.52251
# 10    01  05  0.51604

# %%
# 월별 검색 평균 구하기

total=[]
for j in range(len(peperoDF.month.unique())):
    for i in range(len(peperoDF)):
        if peperoDF.month.iloc[i]==peperoDF.month.unique()[j]:
# Out:
# ['0.49342',
#  '0.56345',
#  '0.58284',
#  '0.52251',
#  '0.51604',
#  '0.52251',
#  '0.52358',
#  '0.48588',
#  '0.51927',
#  '0.55806',
#  '0.59253',
#  '0.5893',
#  '0.47079',
#  '0.44494',
#  '0.44494',
#  '0.4751',
#  '0.49665',
#  '0.50742',
#  '0.47726',
#  '0.49665',
#  '0.45356',
#  '0.48911',
#  '0.42662',
#  '0.45679',
#  '0.53005',
#  '0.48264',
#  '0.54728',
#  '0.60223',
#  '0.47618',
#  '0.42124',
#  '0.46972',
#  '0.53974',
#  '0.53974',
#  '0.4945',
#  '0.45248',
#  '0.45356',
#  '0.44386',
#  '0.44171',
#  '0.47403',
#  '0.4848',
#  '0.4374',
#  '0.39969',
#  '0.40508',
#  '0.54513',
#  '0.89527',
#  '0.56991',
#  '0.49126',
#  '0.42878',
#  '0.45679',
#  '0.39322',
#  '0.39969',
#  '0.39753',
#  '0.41369',
#  '0.42878',
#  '0.35552',
#  '0.3943',
#  '0.34044',
#  '0.37706',
#  '0.35875',
#  '0.37599',
#  '0.3135',
#  '0.36629',
#  '0.35875',
#  '0.32643',
#  '0.33397',
#  '0.39861',
#  '0.41046',
#  '0.43416',
#  '0.45463',
#  '0.52574',
#  '0.48911',
# ...

# %%
type(peperoDF.month.iloc[0])
# Out:
# str

# %%
type(peperoDF.month.unique()[0])
# Out:
# str

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]=(20,10)#그래프 사이즈 설정
plt.plot(dataDF.date[:10],dataDF.pepero[:10])
plt.show()
