# %% [markdown]
# # 어린이날과 크리스마스에 대한 분석

# %%
# 모듈로딩
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import dates
from matplotlib import font_manager as fm ,rc

# %%
# 한글 폰트 설정
FONT_PATH='./Fonts/malgun.ttf'
font_name=fm.FontProperties(fname=FONT_PATH).get_name()
rc('font',family=font_name)

# %%
# 파일불러오기
# 검색량 데이터
df_lego=pd.read_excel('./Data_조건영/lego.xlsx',skiprows=6)
df_nintendo=pd.read_excel('./Data_조건영/nintendo.xlsx',skiprows=6)
df_temapark=pd.read_excel('./Data_조건영/temapark.xlsx',skiprows=6)
df_movie=pd.read_excel('./Data_조건영/movie.xlsx',skiprows=6)
df_chi_mas=pd.read_excel('./Data_조건영/5ye_ch_mas.xlsx',skiprows=6)

# 서울대공원 18년도
df20181=pd.read_excel('./Data_조건영/gongwon_2018.xls',skiprows=3,sheet_name='1월').iloc[:-1]
df20182=pd.read_excel('./Data_조건영/gongwon_2018.xls',skiprows=3,sheet_name='2월').iloc[:-1]
df20183=pd.read_excel('./Data_조건영/gongwon_2018.xls',skiprows=3,sheet_name='3월').iloc[:-1]
df20184=pd.read_excel('./Data_조건영/gongwon_2018.xls',skiprows=3,sheet_name='4월').iloc[:-1]
df20185=pd.read_excel('./Data_조건영/gongwon_2018.xls',skiprows=3,sheet_name='5월').iloc[:-1]
df20186=pd.read_excel('./Data_조건영/gongwon_2018.xls',skiprows=3,sheet_name='6월').iloc[:-1]
df20187=pd.read_excel('./Data_조건영/gongwon_2018.xls',skiprows=3,sheet_name='7월').iloc[:-1]
df20188=pd.read_excel('./Data_조건영/gongwon_2018.xls',skiprows=3,sheet_name='8월').iloc[:-1]
df20189=pd.read_excel('./Data_조건영/gongwon_2018.xls',skiprows=3,sheet_name='9월').iloc[:-1]
df201810=pd.read_excel('./Data_조건영/gongwon_2018.xls',skiprows=3,sheet_name='10월').iloc[:-1]
df201811=pd.read_excel('./Data_조건영/gongwon_2018.xls',skiprows=3,sheet_name='11월').iloc[:-1]
df201812=pd.read_excel('./Data_조건영/gongwon_2018.xls',skiprows=3,sheet_name='12월').iloc[:-1]

# 서울대공원 19년도
df20191=pd.read_excel('./Data_조건영/gongwon_202004.xls',skiprows=3,sheet_name='1월')
df20191=pd.read_excel('./Data_조건영/gongwon_202004.xls',skiprows=3,sheet_name='1월').iloc[:-1]
df20192=pd.read_excel('./Data_조건영/gongwon_202004.xls',skiprows=3,sheet_name='2월').iloc[:-1]
df20193=pd.read_excel('./Data_조건영/gongwon_202004.xls',skiprows=3,sheet_name='3월').iloc[:-1]
df20194=pd.read_excel('./Data_조건영/gongwon_202004.xls',skiprows=3,sheet_name='4월').iloc[:-1]
df20195=pd.read_excel('./Data_조건영/gongwon_202004.xls',skiprows=4,sheet_name='5월')
df20196=pd.read_excel('./Data_조건영/gongwon_202004.xls',skiprows=4,sheet_name='6월')
df20197=pd.read_excel('./Data_조건영/gongwon_202004.xls',skiprows=4,sheet_name='7월')
df20198=pd.read_excel('./Data_조건영/gongwon_202004.xls',skiprows=4,sheet_name='8월')
df20199=pd.read_excel('./Data_조건영/gongwon_202004.xls',skiprows=4,sheet_name='9월')
df201910=pd.read_excel('./Data_조건영/gongwon_202004.xls',skiprows=4,sheet_name='10월')
df201911=pd.read_excel('./Data_조건영/gongwon_202004.xls',skiprows=4,sheet_name='11월')
df201912=pd.read_excel('./Data_조건영/gongwon_202004.xls',skiprows=4,sheet_name='12월')

# .iloc[:-1]을 하는 이유는 제일 밑행에 합계열이 있는 데이터가 있어서 없애주기 위해 사용
# Out:
# c:\ProgramData\Anaconda3\envs\EV_PY39\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\ProgramData\Anaconda3\envs\EV_PY39\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\ProgramData\Anaconda3\envs\EV_PY39\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\ProgramData\Anaconda3\envs\EV_PY39\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %% [markdown]
# - 데이터 출처
#     - 검색량 => 네이버 랩
#     - 서울대공원 => https://data.seoul.go.kr/dataList/OA15386/F/1/datasetView.do;jsessionid=BB4A392C7A63405BF372F9FD1407F38F.new_portal-svr-21#

# %%
# 5년간 크리스마스와 어린이날 검색량
df_chi_mas=df_chi_mas.iloc[:,[0,1,3]]

# %%
df_chi_mas_ymd=pd.concat([df_chi_mas,df_chi_mas['날짜'].str.split('-',expand=True)],axis=1)
df_chi_mas_ymd.rename(columns={0:'년',1:'월',2:'일'},inplace=True)
df_chi_mas_ymd
# Out:
#               날짜      어린이날     크리스마스     년   월   일
# 0     2017-04-01  18.51844   8.69879  2017  04  01
# 1     2017-04-02  17.76730   8.01024  2017  04  02
# 2     2017-04-03  14.53581   8.61077  2017  04  03
# 3     2017-04-04  14.67469   8.66554  2017  04  04
# 4     2017-04-05  14.63362   8.81812  2017  04  05
# ...          ...       ...       ...   ...  ..  ..
# 1883  2022-05-28  22.85708  11.12436  2022  05  28
# 1884  2022-05-29  24.98924  10.73119  2022  05  29
# 1885  2022-05-30  20.72884  11.11458  2022  05  30
# 1886  2022-05-31  22.69473  11.35714  2022  05  31
# 1887  2022-06-01  40.36031  10.72532  2022  06  01
#
# [1888 rows x 6 columns]

# %%
# 5년간 어린이날 검색량 평균
df_chi_mas_ymd['어린이날'].mean()
# Out:
# 20.518554179025426

# %%
# 5년간 크리스마스 검색량 평균
df_chi_mas_ymd['크리스마스'].mean()
# Out:
# 13.226684978813548

# %%
# 어린이날과 크리스마스의 검색량만 추출
df_chi_mas_ymd[((df_chi_mas_ymd['월']=='05')&(df_chi_mas_ymd['일']=='05')) | ((df_chi_mas_ymd['월']=='12')&(df_chi_mas_ymd['일']=='25'))]

# 어린이날이든 크리스마스든 각 날에는 서로의 검색량이 높아진다는 것을 확인
# 이것 토대로 이 2개의 날의 협동을 생각해봄
# Out:
#               날짜      어린이날     크리스마스     년   월   일
# 34    2017-05-05  28.03880   9.75313  2017  05  05
# 268   2017-12-25  29.47654  27.96447  2017  12  25
# 399   2018-05-05  35.51699  12.84965  2018  05  05
# 633   2018-12-25  33.57654  26.45827  2018  12  25
# 764   2019-05-05  29.11857  11.23586  2019  05  05
# 998   2019-12-25  42.56680  28.48284  2019  12  25
# 1130  2020-05-05  67.91987  16.05962  2020  05  05
# 1364  2020-12-25  77.82559  42.01126  2020  12  25
# 1495  2021-05-05  67.41324  14.56515  2021  05  05
# 1729  2021-12-25  64.11134  61.51363  2021  12  25
# 1860  2022-05-05  70.33957  14.49473  2022  05  05

# %%
# 5년간 크리스마스와 어린이날 검색량
df_chi_mas.set_index('날짜',inplace=True)

# 합계 열이 2개있어나 하나의 열은 삭제

# %%
# 5년간 크리스마스와 어린이날 검색량
plt.figure(figsize=(25,8))
plt.plot(df_chi_mas)
plt.rc('font',size=20)
plt.title('5년간 크리스마스와 어린이날 검색량')
plt.legend(['어린이날','크리스마스'])
ax = plt.gca() # 현재의 Axes를 보여줌
ax.xaxis.set_major_locator(dates.YearLocator(month=2,day=4)) # 4월 1일 기준
plt.show()

# %%
# 레로,닌텐도,놀이공원 데이터 합쳐서 년월일로 구분하기
df_lnt=pd.concat([df_lego,df_nintendo,df_temapark],axis=1).iloc[:,[0,1,3,5]]
df_lnt_ymd=pd.concat([df_lnt,df_lnt['날짜'].str.split('-',expand=True)],axis=1).rename(columns={0:'년',1:'월',2:'일'})
df_lnt_ymd
# Out:
#              날짜        레고       닌텐도      놀이공원     년   월   일
# 0    2021-07-10  32.55778  38.05876  13.14007  2021  07  10
# 1    2021-07-11  32.96373  37.26945  12.60197  2021  07  11
# 2    2021-07-12  28.34378  31.92403  11.43898  2021  07  12
# 3    2021-07-13  28.03174  31.77555  11.23068  2021  07  13
# 4    2021-07-14  31.25511  29.18880   9.98090  2021  07  14
# ..          ...       ...       ...       ...   ...  ..  ..
# 361  2022-07-06  24.75082  28.11034  10.76202  2022  07  06
# 362  2022-07-07  23.39361  30.93935  10.98767  2022  07  07
# 363  2022-07-08  25.19615  30.43919  11.38691  2022  07  08
# 364  2022-07-09  27.85300  37.62113  14.61551  2022  07  09
# 365  2022-07-10  31.29146  39.07471  16.00416  2022  07  10
#
# [366 rows x 7 columns]

# %%
# 어린이날과 크리스마스 데이터만 추출
df_lnt_ymd[((df_lnt_ymd['월']=='05')&(df_lnt_ymd['일']=='05')) | ((df_lnt_ymd['월']=='12')&(df_lnt_ymd['일']=='25'))]

# 크리스마스의 놀이공원의 검색량이 엄청 났을 것을 확인!!!!!
# Out:
#              날짜        레고       닌텐도      놀이공원     년   월   일
# 168  2021-12-25  92.43236  100.0000   13.4178  2021  12  25
# 299  2022-05-05  87.80635   87.7618  100.0000  2022  05  05

# %%
# 레고 검색량
df_lego_index=df_lego.set_index('날짜')

# %%
# 닌텐도 검색량
df_nintendo_index=df_nintendo.set_index('날짜')

# %%
# 놀이공원 검색량
df_temaparko_index=df_temapark.set_index('날짜')

# %%
# 1년간 레고, 닌텐도, 놀이공원 검색량
plt.figure(figsize=(20,5))
plt.plot(df_lego_index)
plt.plot(df_nintendo_index)
plt.plot(df_temaparko_index)
plt.rc('font',size=20)
plt.title('1년간 레고, 닌텐도, 놀이공원 검색량')
plt.legend(['레고','닌텐도','놀이공원'])
ax = plt.gca()
ax.xaxis.set_major_locator(dates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
df_movie['날짜']=pd.to_datetime(df_movie['날짜'])
df_movie_index=df_movie.set_index('날짜')

# %% [markdown]
# ### 영화관 검색량

# %%
df_movie_index.plot(kind='line',figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='날짜'>

# %% [markdown]
# ### 서울 대공원 입장객 현황

# %%
# 2018년도 데이터 합치기
df_2018=pd.concat([df20181,df20182,df20183,df20184,df20185,df20186,df20187,df20188,df20189,df201810,df201811,df201812])

# %%
# 2018년도 데이터 확인하기
print(df_2018.info())
print(df_2018['날짜'].unique())

# 행이 365이고 유니크로 값이 다 시간데이터라는 것을 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 0 to 30
# Data columns (total 23 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      365 non-null    object
#  1   요일      365 non-null    object
#  2   날씨      343 non-null    object
#  3   유료합계    365 non-null    int64
#  4   무료합계    365 non-null    int64
#  5   총계      365 non-null    int64
#  6   외국인계    365 non-null    int64
#  7   유료소계    365 non-null    int64
#  8   어른      365 non-null    int64
#  9   청소년     365 non-null    int64
#  10  어린이     365 non-null    int64
#  11  외국인     365 non-null    int64
#  12  단체입장    365 non-null    int64
#  13  무료소계    365 non-null    int64
#  14  총계.1    365 non-null    int64
#  15  유료소계.1  365 non-null    int64
#  16  어른.1    365 non-null    int64
#  17  청소년.1   365 non-null    int64
#  18  어린이.1   365 non-null    int64
#  19  외국인.1   365 non-null    int64
#  20  단체입장.1  365 non-null    int64
# ...

# %%
# 필요한 열만 추출
df_2018_final=df_2018.iloc[:,[0,5,14,22]]
df_2018_final.rename(columns={'총계':'총 인원수','총계.1':'동/식물원 입장 수','총계.2':'테마가든 입장 수'},inplace=True)
df_2018_final
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9480\711945716.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018_final.rename(columns={'총계':'총 인원수','총계.1':'동/식물원 입장 수','총계.2':'테마가든 입장 수'},inplace=True)
#                      날짜  총 인원수  동/식물원 입장 수  테마가든 입장 수
# 0   2018-01-01 00:00:00   2316        2302         14
# 1   2018-01-02 00:00:00    988         979          9
# 2   2018-01-03 00:00:00    694         693          1
# 3   2018-01-04 00:00:00    671         651         20
# 4   2018-01-05 00:00:00    758         755          3
# ..                  ...    ...         ...        ...
# 26  2018-12-27 00:00:00   3943        3916         27
# 27  2018-12-28 00:00:00    357         328         29
# 28  2018-12-29 00:00:00    734         708         26
# ...

# %%
# 2019년도 데이터 합치기
df_2019_1_4=pd.concat([df20191,df20192,df20193,df20194])
df_2019_5_12=pd.concat([df20195,df20196,df20197,df20198,df20199,df201910,df201911,df201912])
df_2019_5_12.columns=['날짜', '요일', '날씨', '유료합계', '무료합계', '총계', '외국인계', '유료소계', '어른', '청소년',
       '어린이', '외국인', '단체입장', '무료소계', '총계.1', '유료소계.1', '어른.1', '청소년.1',
       '어린이.1', '외국인.1', '단체입장.1', '무료소계.1', '총계.2']
df_2019=pd.concat([df_2019_1_4,df_2019_5_12])
df_2019
# Out:
#                      날짜 요일     날씨  유료합계  무료합계    총계  외국인계  유료소계    어른  청소년  \
# 0   2019-01-01 00:00:00  화  구름 조금   919   605  1524    54   912   770   48
# 1   2019-01-02 00:00:00  수     맑음   175   459   634    11   175   147   14
# 2   2019-01-03 00:00:00  목     맑음   182   595   777    16   182   153    8
# 3   2019-01-04 00:00:00  금  구름 많음   181   509   690     3   176   139   14
# 4   2019-01-05 00:00:00  토    NaN   740   861  1601    16   734   615   32
# ..                  ... ..    ...   ...   ...   ...   ...   ...   ...  ...
# 26  2019-12-27 00:00:00  금     맑음   819   483  1302   404   816   274  519
# 27  2019-12-28 00:00:00  토     흐림  1074  1036  2110   404  1049   862   47
# 28  2019-12-29 00:00:00  일    NaN  6067   846  6913   404  6059  4585  173
# 29  2019-12-30 00:00:00  월    NaN   413   450   863   404   411   347   22
# 30  2019-12-31 00:00:00  화    NaN   189   359   548   404   185   164    7
#
# ...

# %%
# 데이터 정보확인
df_2019.info()

# 1년은 365일인데 364일 인것을 확인할 수 있음
# 왜 그럴까 df1에서 부터 df12까지 info()를 써보기로 함
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 364 entries, 0 to 30
# Data columns (total 23 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      364 non-null    object
#  1   요일      364 non-null    object
#  2   날씨      219 non-null    object
#  3   유료합계    364 non-null    int64
#  4   무료합계    364 non-null    int64
#  5   총계      364 non-null    int64
#  6   외국인계    364 non-null    int64
#  7   유료소계    364 non-null    int64
#  8   어른      364 non-null    int64
#  9   청소년     364 non-null    int64
#  10  어린이     364 non-null    int64
#  11  외국인     364 non-null    int64
#  12  단체입장    364 non-null    int64
#  13  무료소계    364 non-null    int64
#  14  총계.1    364 non-null    int64
#  15  유료소계.1  364 non-null    int64
#  16  어른.1    364 non-null    int64
#  17  청소년.1   364 non-null    int64
#  18  어린이.1   364 non-null    int64
#  19  외국인.1   364 non-null    int64
#  20  단체입장.1  364 non-null    int64
# ...

# %%
# 각 월별 데이터 정보확인
df20199.info()

# 9월은 30일 인데 29개라는 것을 확인
# df9자체를 확인해보기로 함
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 23 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   29 non-null     datetime64[ns]
#  1   Unnamed: 1   29 non-null     object
#  2   Unnamed: 2   21 non-null     object
#  3   Unnamed: 3   29 non-null     int64
#  4   Unnamed: 4   29 non-null     int64
#  5   Unnamed: 5   29 non-null     int64
#  6   Unnamed: 6   29 non-null     int64
#  7   Unnamed: 7   29 non-null     int64
#  8   Unnamed: 8   29 non-null     int64
#  9   Unnamed: 9   29 non-null     int64
#  10  Unnamed: 10  29 non-null     int64
#  11  Unnamed: 11  29 non-null     int64
#  12  Unnamed: 12  29 non-null     int64
#  13  Unnamed: 13  29 non-null     int64
#  14  Unnamed: 14  29 non-null     int64
#  15  Unnamed: 15  29 non-null     int64
#  16  Unnamed: 16  29 non-null     int64
#  17  Unnamed: 17  29 non-null     int64
# ...

# %%
# df9 데이터 값 확인
df20199

# 9월 7일이 없는 것을 확인!!!
# 2019년 9월 7일은 8일까지 무료로 진행되는 영화제 행사가 있었다는데
# 왜 빠졌는지는 모르겠음
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0  2019-09-01          일      구름 많음       10416        4006       14422
# 1  2019-09-02          월         흐림        1127         867        1994
# 2  2019-09-03          화          비         806         984        1790
# 3  2019-09-04          수          비          77         383         460
# 4  2019-09-05          목          비         307         457         764
# 5  2019-09-06          금      구름 많음         517         481         998
# 6  2019-09-08          일        NaN        4444        1589        6033
# 7  2019-09-09          월        NaN         370         555         925
# 8  2019-09-10          화        NaN         537         450         987
# 9  2019-09-11          수         흐림        1068         702        1770
# 10 2019-09-12          목          비        4032        1428        5460
# 11 2019-09-13          금         맑음       14805        5017       19822
# ...

# %%
# 19년도 데이터에서 필요한 열만 추출
df_2019_final=df_2019.iloc[:,[0,5,14,22]]
df_2019_final.rename(columns={'총계':'총 인원수','총계.1':'동/식물원 입장 수','총계.2':'테마가든 입장 수'},inplace=True)
df_2019_final
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9480\1671647542.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019_final.rename(columns={'총계':'총 인원수','총계.1':'동/식물원 입장 수','총계.2':'테마가든 입장 수'},inplace=True)
#                      날짜  총 인원수  동/식물원 입장 수  테마가든 입장 수
# 0   2019-01-01 00:00:00   1524        1493         31
# 1   2019-01-02 00:00:00    634         621         13
# 2   2019-01-03 00:00:00    777         761         16
# 3   2019-01-04 00:00:00    690         660         30
# 4   2019-01-05 00:00:00   1601        1576         25
# ..                  ...    ...         ...        ...
# 26  2019-12-27 00:00:00   1302        1271         31
# 27  2019-12-28 00:00:00   2110        2046         64
# 28  2019-12-29 00:00:00   6913        6866         47
# ...

# %%
# 18년도 19년도 데이터 합치기
df_1819=pd.concat([df_2018_final,df_2019_final])
df_1819
# Out:
#                      날짜  총 인원수  동/식물원 입장 수  테마가든 입장 수
# 0   2018-01-01 00:00:00   2316        2302         14
# 1   2018-01-02 00:00:00    988         979          9
# 2   2018-01-03 00:00:00    694         693          1
# 3   2018-01-04 00:00:00    671         651         20
# 4   2018-01-05 00:00:00    758         755          3
# ..                  ...    ...         ...        ...
# 26  2019-12-27 00:00:00   1302        1271         31
# 27  2019-12-28 00:00:00   2110        2046         64
# 28  2019-12-29 00:00:00   6913        6866         47
# 29  2019-12-30 00:00:00    863         840         23
# 30  2019-12-31 00:00:00    548         529         19
#
# [729 rows x 4 columns]

# %%
# 데이터 확인
df_1819.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 729 entries, 0 to 30
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   날짜          729 non-null    object
#  1   총 인원수       729 non-null    int64
#  2   동/식물원 입장 수  729 non-null    int64
#  3   테마가든 입장 수   729 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 28.5+ KB

# %%
# 타입바꾸기
df_1819['날짜']=pd.to_datetime(df_1819['날짜'])
df_1819.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 729 entries, 0 to 30
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   날짜          729 non-null    datetime64[ns]
#  1   총 인원수       729 non-null    int64
#  2   동/식물원 입장 수  729 non-null    int64
#  3   테마가든 입장 수   729 non-null    int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 28.5 KB

# %%
# 각 날짜의 입장객 수의 순위
df_1819.sort_values('총 인원수',ascending=False)
# Out:
#            날짜  총 인원수  동/식물원 입장 수  테마가든 입장 수
# 4  2018-05-05  52310       49406       2904
# 4  2019-05-05  43255       41307       1948
# 12 2019-04-13  39200       35225       3975
# 18 2018-05-19  33655       29153       4502
# 6  2018-05-07  32821       29757       3064
# ..        ...    ...         ...        ...
# 22 2018-04-23    288         248         40
# 11 2018-01-12    228         228          0
# 25 2018-01-26    222         222          0
# 24 2018-01-25    162         162          0
# 23 2018-01-24    128         128          0
#
# [729 rows x 4 columns]

# %%
# 어린이날과 크리스마스 입장객수 알아보기
chi_mas_su=df_1819[(df_1819['날짜']=='2018-05-05') | (df_1819['날짜']=='2018-12-25') | (df_1819['날짜']=='2019-05-05') | (df_1819['날짜']=='2019-12-25')]
chi_mas_su
# Out:
#            날짜  총 인원수  동/식물원 입장 수  테마가든 입장 수
# 4  2018-05-05  52310       49406       2904
# 24 2018-12-25   2402        2379         23
# 4  2019-05-05  43255       41307       1948
# 24 2019-12-25   2858        2796         62

# %%
chi_mas_su['동/식물원 입장 비율']=chi_mas_su['동/식물원 입장 수']/chi_mas_su['총 인원수']*100
chi_mas_su['테마가든 입장 비율']=chi_mas_su['테마가든 입장 수']/chi_mas_su['총 인원수']*100
chi_mas_su
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9480\212540466.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chi_mas_su['동/식물원 입장 비율']=chi_mas_su['동/식물원 입장 수']/chi_mas_su['총 인원수']*100
# C:\Users\User\AppData\Local\Temp\ipykernel_9480\212540466.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chi_mas_su['테마가든 입장 비율']=chi_mas_su['테마가든 입장 수']/chi_mas_su['총 인원수']*100
#            날짜  총 인원수  동/식물원 입장 수  테마가든 입장 수  동/식물원 입장 비율  테마가든 입장 비율
# ...

# %%
# 서울대공원의 2019년 일일 입장객 수 그래프
df_1819.plot('날짜',['동/식물원 입장 수','테마가든 입장 수'],kind='line',figsize=(20,8))
plt.show()

# 5월 5일이 가장 제일 위에 있고
# 12월 25일은 추운 겨울인 12월인 다른 날에 비해 높게 쏟아있음
