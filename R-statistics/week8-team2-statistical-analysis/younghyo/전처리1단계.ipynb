# %%
import pandas as pd
import os

# %%
path = 'C:/RProject/team2_orange/younghyo/AmongUsData/'
files = os.listdir(path)
df = pd.concat([pd.read_csv(path + i) for i in files ])
df = df.reset_index(drop=True)

# %%
df.drop(['Game Completed Date', 'Rank Change', 'Region/Game Code'], axis = 1, inplace = True)

# %%
df.replace('-', '', inplace = True)

# %%
df
# Out:
#           Team Outcome Task Completed All Tasks Completed Murdered  \
# 0     Crewmate     Win              3                  No      Yes
# 1     Crewmate    Loss              7                 Yes       No
# 2     Crewmate     Win              3                  No       No
# 3     Imposter     Win
# 4     Crewmate    Loss              4                  No       No
# ...        ...     ...            ...                 ...      ...
# 2222  Imposter    Loss
# 2223  Crewmate    Loss              7                 Yes      Yes
# 2224  Crewmate     Win              7                 Yes      Yes
# 2225  Crewmate    Loss              7                 Yes       No
# 2226  Crewmate    Loss              8                 Yes      Yes
#
#      Imposter Kills Game Length Ejected  Sabotages Fixed  \
# 0                       07m 04s      No              2.0
# 1                       16m 21s      No              1.0
# 2                       11m 33s      No              0.0
# ...

# %%
int(df['Game Length'][0].split()[0][:2])*60 + int(df['Game Length'][0].split()[1][:2])
# Out:
# 424

# %%
for i in range(len(df.index)):
    df['Game Length'][i] = int(df['Game Length'][i].split()[0][:2])*60 + int(df['Game Length'][i].split()[1][:2])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16656\3025024952.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Game Length'][i] = int(df['Game Length'][i].split()[0][:2])*60 + int(df['Game Length'][i].split()[1][:2])

# %%
df.columns = ['Team', 'Outcome', 'Task_Completed', 'All_Tasks_Completed', 'Murdered',
       'Imposter_Kills', 'Game_Length', 'Ejected', 'Sabotages_Fixed',
       'Time_to_complete_all_tasks']

# %%
df
# Out:
#           Team Outcome Task_Completed All_Tasks_Completed Murdered  \
# 0     Crewmate     Win              3                  No      Yes
# 1     Crewmate    Loss              7                 Yes       No
# 2     Crewmate     Win              3                  No       No
# 3     Imposter     Win
# 4     Crewmate    Loss              4                  No       No
# ...        ...     ...            ...                 ...      ...
# 2222  Imposter    Loss
# 2223  Crewmate    Loss              7                 Yes      Yes
# 2224  Crewmate     Win              7                 Yes      Yes
# 2225  Crewmate    Loss              7                 Yes       No
# 2226  Crewmate    Loss              8                 Yes      Yes
#
#      Imposter_Kills Game_Length Ejected  Sabotages_Fixed  \
# 0                           424      No              2.0
# 1                           981      No              1.0
# 2                           693      No              0.0
# ...

# %%
df.to_csv(path + 'amongus.csv', index = False)
